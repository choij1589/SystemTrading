# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
# Hyperparameters
learning_rate = 0.001
gamma = 0.98

# %%
from binance import Client
client = Client()
klines = np.array(client.futures_historical_klines("ETHUSDT", Client.KLINE_INTERVAL_1HOUR, "1 Jan, 2015"))
sample = pd.DataFrame(klines.reshape(-1, 12), dtype=float, columns=['datetime',
                                                                   'open',
                                                                   'high',
                                                                   'low',
                                                                   'close',
                                                                   'volume',
                                                                   'close time',
                                                                   'quote asset volume, number of trades',
                                                                   'number of trades',
                                                                   'taker buy base asset volume',
                                                                   'taker buy quote asset volume',
                                                                   'ignore'])
sample['datetime'] = pd.to_datetime(sample['datetime'], unit='ms')
sample.set_index('datetime', inplace=True)
sample = sample[['open', 'high', 'low', 'close', 'volume']]

# %%
# make states
# first make a band for 7 hours, 16 hours, 30 hours, 200 hours, 1500 hours
sample['p7-center'] = sample['close'].rolling(7).mean()
sample['p7-upper'] = sample['p7-center'] + 2.*sample['close'].rolling(7).std()
sample['p7-lower'] = sample['p7-center'] - 2.*sample['close'].rolling(7).std()
sample['p7-vcenter'] = sample['volume'].rolling(7).mean()
sample['p7-vupper'] = sample['p7-center'] + 2.*sample['volume'].rolling(7).std()
sample['p7-vlower'] = sample['p7-center'] - 2.*sample['volume'].rolling(7).std()

sample['p16-center'] = sample['close'].rolling(16).mean()
sample['p16-upper'] = sample['p16-center'] + 2.*sample['close'].rolling(16).std()
sample['p16-lower'] = sample['p16-center'] - 2.*sample['close'].rolling(16).std()
sample['p16-vcenter'] = sample['volume'].rolling(16).mean()
sample['p16-vupper'] = sample['p16-center'] + 2.*sample['volume'].rolling(16).std()
sample['p16-vlower'] = sample['p16-center'] - 2.*sample['volume'].rolling(16).std()

sample['p30-center'] = sample['close'].rolling(30).mean()
sample['p30-upper'] = sample['p30-center'] + 2.*sample['close'].rolling(30).std()
sample['p30-lower'] = sample['p30-center'] - 2.*sample['close'].rolling(30).std()
sample['p30-vcenter'] = sample['volume'].rolling(30).mean()
sample['p30-vupper'] = sample['p30-center'] + 2.*sample['volume'].rolling(30).std()
sample['p30-vlower'] = sample['p30-center'] - 2.*sample['volume'].rolling(30).std()

sample['p200-center'] = sample['close'].rolling(200).mean()
sample['p200-upper'] = sample['p200-center'] + 2.*sample['close'].rolling(200).std()
sample['p200-lower'] = sample['p200-center'] - 2.*sample['close'].rolling(200).std()
sample['p200-vcenter'] = sample['volume'].rolling(200).mean()
sample['p200-vupper'] = sample['p200-center'] + 2.*sample['volume'].rolling(200).std()
sample['p200-vlower'] = sample['p200-center'] - 2.*sample['volume'].rolling(200).std()

sample['p1500-center'] = sample['close'].rolling(7).mean()
sample['p1500-upper'] = sample['p1500-center'] + 2.*sample['close'].rolling(1500).std()
sample['p1500-lower'] = sample['p1500-center'] - 2.*sample['close'].rolling(1500).std()
sample['p1500-vcenter'] = sample['volume'].rolling(7).mean()
sample['p1500-vupper'] = sample['p1500-center'] + 2.*sample['volume'].rolling(1500).std()
sample['p1500-vlower'] = sample['p1500-center'] - 2.*sample['volume'].rolling(1500).std()

# %%
sample['p7-open'] = (sample['open'] - sample['p7-lower']) / (sample['p7-upper'] - sample['p7-lower'])
sample['p7-high'] = (sample['high'] - sample['p7-lower']) / (sample['p7-upper'] - sample['p7-lower'])
sample['p7-low'] = (sample['low'] - sample['p7-lower']) / (sample['p7-upper'] - sample['p7-lower'])
sample['p7-close'] = (sample['close'] - sample['p7-lower']) / (sample['p7-upper'] - sample['p7-lower'])
sample['p7-volume'] = (sample['volume'] - sample['p7-vlower']) / (sample['p7-vupper'] - sample['p7-vlower'])

sample['p16-open'] = (sample['open'] - sample['p16-lower']) / (sample['p16-upper'] - sample['p16-lower'])
sample['p16-high'] = (sample['high'] - sample['p16-lower']) / (sample['p16-upper'] - sample['p16-lower'])
sample['p16-low'] = (sample['low'] - sample['p16-lower']) / (sample['p16-upper'] - sample['p16-lower'])
sample['p16-close'] = (sample['close'] - sample['p16-lower']) / (sample['p16-upper'] - sample['p16-lower'])
sample['p16-volume'] = (sample['volume'] - sample['p16-vlower']) / (sample['p16-vupper'] - sample['p16-vlower'])

sample['p30-open'] = (sample['open'] - sample['p30-lower']) / (sample['p30-upper'] - sample['p30-lower'])
sample['p30-high'] = (sample['high'] - sample['p30-lower']) / (sample['p30-upper'] - sample['p30-lower'])
sample['p30-low'] = (sample['low'] - sample['p30-lower']) / (sample['p30-upper'] - sample['p30-lower'])
sample['p30-close'] = (sample['close'] - sample['p30-lower']) / (sample['p30-upper'] - sample['p30-lower'])
sample['p30-volume'] = (sample['volume'] - sample['p30-vlower']) / (sample['p30-vupper'] - sample['p30-vlower'])

sample['p200-open'] = (sample['open'] - sample['p200-lower']) / (sample['p200-upper'] - sample['p200-lower'])
sample['p200-high'] = (sample['high'] - sample['p200-lower']) / (sample['p200-upper'] - sample['p200-lower'])
sample['p200-low'] = (sample['low'] - sample['p200-lower']) / (sample['p200-upper'] - sample['p200-lower'])
sample['p200-close'] = (sample['close'] - sample['p200-lower']) / (sample['p200-upper'] - sample['p200-lower'])
sample['p200-volume'] = (sample['volume'] - sample['p200-vlower']) / (sample['p200-vupper'] - sample['p200-vlower'])

sample['p1500-open'] = (sample['open'] - sample['p1500-lower']) / (sample['p1500-upper'] - sample['p1500-lower'])
sample['p1500-high'] = (sample['high'] - sample['p1500-lower']) / (sample['p1500-upper'] - sample['p1500-lower'])
sample['p1500-low'] = (sample['low'] - sample['p1500-lower']) / (sample['p1500-upper'] - sample['p1500-lower'])
sample['p1500-close'] = (sample['close'] - sample['p1500-lower']) / (sample['p1500-upper'] - sample['p1500-lower'])
sample['p1500-volume'] = (sample['volume'] - sample['p1500-vlower']) / (sample['p1500-vupper'] - sample['p1500-vlower'])

sample.dropna(inplace=True)

# %%
cut1 = int(len(sample)*0.8)
cut2 = int(len(sample)*0.85)
train_sample, val_sample, test_sample = sample.iloc[:cut1], sample.iloc[cut1:cut2], sample.iloc[cut2:]

# %%
### Evaluated buy and hold strategy for train, validation, test samples
book = train_sample[['close']].copy()
book['number'] = book.index.map(mdates.date2num)
book['reward'] = 1. + book['close'].pct_change()
book['total_reward'] = book['reward'].cumprod()

CAGR = book['total_reward'].iloc[-1]**(365*24/len(book.index)) - 1.
historical_max = book['total_reward'].cummax()
daily_drawdown = book['total_reward']/historical_max - 1.
historical_dd = daily_drawdown.cummin()
MDD = historical_dd.min()
VOL = np.std(book['reward'])*np.sqrt(365.*24)
Sharpe = (np.mean(book['reward'])/np.std(book['reward'])*np.sqrt(365.*24))

print("==== BUY AND HOLD ====")
print(f"Accumulated Returns: {(book['total_reward'].iloc[-1]-1.)*100:.2f} %")
print(f"CAGR: {CAGR*100:.2f} %")
print(f"MDD: {MDD*100:.2f} %")
print(f"VOL: {VOL*100:.2f}%")
print(f"Sharpe: {Sharpe*100:.2f} %")
# Out:
# ==== BUY AND HOLD ====
# Accumulated Returns: 1888.55 %
# CAGR: 365.87 %
# MDD: -66.59 %
# VOL: 102.29%
# Sharpe: 856598.56 %

# %%
### Evaluated buy and hold strategy for train, validation, test samples
book = val_sample[['close']].copy()
book['number'] = book.index.map(mdates.date2num)
book['reward'] = 1. + book['close'].pct_change()
book['total_reward'] = book['reward'].cumprod()

CAGR = book['total_reward'].iloc[-1]**(365*24/len(book.index)) - 1.
historical_max = book['total_reward'].cummax()
daily_drawdown = book['total_reward']/historical_max - 1.
historical_dd = daily_drawdown.cummin()
MDD = historical_dd.min()
VOL = np.std(book['reward'])*np.sqrt(365.*24)
Sharpe = (np.mean(book['reward'])/np.std(book['reward'])*np.sqrt(365.*24))

print("==== BUY AND HOLD ====")
print(f"Accumulated Returns: {(book['total_reward'].iloc[-1]-1.)*100:.2f} %")
print(f"CAGR: {CAGR*100:.2f} %")
print(f"MDD: {MDD*100:.2f} %")
print(f"VOL: {VOL*100:.2f}%")
print(f"Sharpe: {Sharpe*100:.2f} %")
# Out:
# ==== BUY AND HOLD ====
# Accumulated Returns: -21.21 %
# CAGR: -85.95 %
# MDD: -35.62 %
# VOL: 90.79%
# Sharpe: 964722.93 %

# %%
### Evaluated buy and hold strategy for train, validation, test samples
book = test_sample[['close']].copy()
book['number'] = book.index.map(mdates.date2num)
book['reward'] = 1. + book['close'].pct_change()
book['total_reward'] = book['reward'].cumprod()

CAGR = book['total_reward'].iloc[-1]**(365*24/len(book.index)) - 1.
historical_max = book['total_reward'].cummax()
daily_drawdown = book['total_reward']/historical_max - 1.
historical_dd = daily_drawdown.cummin()
MDD = historical_dd.min()
VOL = np.std(book['reward'])*np.sqrt(365.*24)
Sharpe = (np.mean(book['reward'])/np.std(book['reward'])*np.sqrt(365.*24))

print("==== BUY AND HOLD ====")
print(f"Accumulated Returns: {(book['total_reward'].iloc[-1]-1.)*100:.2f} %")
print(f"CAGR: {CAGR*100:.2f} %")
print(f"MDD: {MDD*100:.2f} %")
print(f"VOL: {VOL*100:.2f}%")
print(f"Sharpe: {Sharpe*100:.2f} %")
# Out:
# ==== BUY AND HOLD ====
# Accumulated Returns: -59.20 %
# CAGR: -91.46 %
# MDD: -74.51 %
# VOL: 95.22%
# Sharpe: 919729.58 %

# %%
class Environment():
    def __init__(self, sample):
        self.sample = sample[
                        ['open', 'high', 'low', 'close', 'volume',
                         'p7-open', 'p7-high', 'p7-low', 'p7-close', 'p7-volume',
                         'p16-open', 'p16-high', 'p16-low', 'p16-close', 'p16-volume',
                         'p30-open', 'p30-high', 'p30-low', 'p30-close', 'p30-volume',
                         'p200-open', 'p200-high', 'p200-low', 'p200-close', 'p200-volume',
                         'p1500-open', 'p1500-high', 'p1500-low', 'p1500-close', 'p1500-volume']
                        ].copy()
        self.episode = None
        self.epi_idx = 0
        
    def make_episode(self, start_idx=-1):
        # check start index
        if start_idx > len(self.sample) - 2000:
            print(f"start_idx should be smaller than {len(self.sample)-200}")
            raise(ValueError)
        if start_idx == -1:
            start_idx = random.randint(0, len(self.sample)-200)
            
        # make an episode
        self.episode = self.sample[start_idx:start_idx+2000]
        self.epi_idx = 0
        first_state = self.episode.iloc[self.epi_idx].to_numpy()[5:]
        return first_state
    
    def step(self, action):
        if action == 0: action = "short"
        elif action == 1: action = "hold"
        elif action == 2: action = "long"
        else: exit()
        
        this_close = self.episode.iloc[self.epi_idx].to_numpy()[3]
        
        self.epi_idx += 1
        
        # is done?
        done = True if self.epi_idx == 200-1 else False
        
        # make state
        state = self.episode.iloc[self.epi_idx].to_numpy()[5:]
        
        # make reward
        next_high = self.episode.iloc[self.epi_idx].to_numpy()[1]
        next_low = self.episode.iloc[self.epi_idx].to_numpy()[2]
        next_close = self.episode.iloc[self.epi_idx].to_numpy()[3]
        reward = np.log(random.uniform(next_low, next_high)/this_close)
        
        if action == "long":    reward -= 0.002
        elif action == "short": reward = -1*reward - 0.002
        else:                   reward = -0.002
        
        # index and ohlcv
        info = (self.epi_idx, self.episode.iloc[self.epi_idx].to_numpy()[:5])
        
        return (state, reward, done, info)

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        # nonliear aggregation of ohlcv
        self.agg1 = nn.Linear(5, 5, bias=True)
        self.agg2 = nn.Linear(5, 5, bias=True)
        self.agg3 = nn.Linear(5, 5, bias=True)
        self.agg4 = nn.Linear(5, 5, bias=True)
        self.agg5 = nn.Linear(5, 5, bias=True) 
        
        self.fc1 = nn.Linear(25, 128, bias=True)
        self.fc2 = nn.Linear(128, 256, bias=True)
        self.fc3 = nn.Linear(256, 64, bias=True)
        self.fc4 = nn.Linear(64, 3)
        self.dropout = nn.Dropout(p=0.2)
        self.optimizer = optim.AdamW(self.parameters(), lr=learning_rate)
        
        # history
        self.episodes = 0
        self.scores = list()
        self.loss = list()
        
    def forward(self, x):
        agg1 = F.relu(self.agg1(x[0:5]))
        agg2 = F.relu(self.agg2(x[5:10]))
        agg3 = F.relu(self.agg3(x[10:15]))
        agg4 = F.relu(self.agg4(x[15:20]))
        agg5 = F.relu(self.agg5(x[20:25]))
        x = torch.concat([agg1, agg2, agg3, agg4, agg5])
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.softmax(self.fc4(x), dim=0)
        
        return x

    def put_data(self, item):
        self.data.append(item)
    
    def train_net(self):
        R = 0.
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma*R
            loss = -R*torch.log(prob)
            loss.backward()
        self.optimizer.step()
        self.data = []
        
        return loss.detach().numpy()

# %%
class History():
    def __init__(self):
        self.episodes = 0
        self.score = []
        self.loss = []
        self.evaluation = {}
        self.evaluation['index'] = []
        self.evaluation['CAGR'] = []
        self.evaluation['MDD'] = []
        self.evaluation['VOL'] = []
        self.evaluation['Sharpe'] = []
    
    def update(self, score, loss):
        self.episodes += 1
        self.score.append(score)
        self.loss.append(loss)
        
    def save_evaluation(self, index, args):
        CAGR, MDD, VOL, Sharpe = args
        self.evaluation['index'].append(index)
        self.evaluation['CAGR'].append(CAGR)
        self.evaluation['MDD'].append(MDD)
        self.evaluation['VOL'].append(VOL)
        self.evaluation['Sharpe'].append(Sharpe)
    
    def plot(self):
        plt.figure(figsize=(15, 8))
        plt.subplot(2, 1, 1)
        plt.plot(range(self.episodes), self.score, 'r--', label='score')
        plt.legend(loc='best')
        
        plt.subplot(2, 1, 2)
        plt.plot(range(self.episodes), self.loss, 'b--', label='loss')
        plt.legend(loc='best')
        
        plt.show()

# %%
#import os
#os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'
env = Environment(train_sample)

#mps = torch.device("mps")
pi = Policy()
train_history = History()
val_history = History()
acc_score = 0.
print_interval = 50

for n_epi in range(50000):
    score= 0.
    state = env.make_episode()
    done = False
    
    while not done:
        prob = pi(torch.from_numpy(state).float())
        m = Categorical(prob)
        action = m.sample()
        next_state, reward, done, info = env.step(action.item())
        pi.put_data((reward, prob[action]))
        state = next_state
        score += reward
        
    pi.train()
    loss = pi.train_net()
    train_history.update(score, loss)
    
    acc_score += score
    if n_epi%print_interval == 0 and n_epi != 0:
        print(f"[EPISODE {n_epi}] avg return: {(np.exp(acc_score/print_interval)-1)*100:.2f}%")
        acc_score = 0.

train_history.plot()
# Out:
# [EPISODE 50] avg return: -31.82%
# [EPISODE 100] avg return: -30.02%
# [EPISODE 150] avg return: -30.72%
# [EPISODE 200] avg return: -27.40%
# [EPISODE 250] avg return: -31.17%
# [EPISODE 300] avg return: -28.03%
# [EPISODE 350] avg return: -30.39%
# [EPISODE 400] avg return: -29.66%
# [EPISODE 450] avg return: -29.01%
# [EPISODE 500] avg return: -29.47%
# [EPISODE 550] avg return: -31.58%
# [EPISODE 600] avg return: -29.55%
# [EPISODE 650] avg return: -28.57%
# [EPISODE 700] avg return: -28.99%
# [EPISODE 750] avg return: -28.01%
# [EPISODE 800] avg return: -30.21%
# [EPISODE 850] avg return: -28.76%
# [EPISODE 900] avg return: -31.59%
# [EPISODE 950] avg return: -29.70%
# [EPISODE 1000] avg return: -29.79%
# [EPISODE 1050] avg return: -32.04%
# [EPISODE 1100] avg return: -27.98%
# [EPISODE 1150] avg return: -28.68%
# [EPISODE 1200] avg return: -29.52%
# [EPISODE 1250] avg return: -31.04%
# [EPISODE 1300] avg return: -29.69%
# [EPISODE 1350] avg return: -27.10%
# [EPISODE 1400] avg return: -27.95%
# [EPISODE 1450] avg return: -28.60%
# [EPISODE 1500] avg return: -27.10%
# [EPISODE 1550] avg return: -26.31%
# [EPISODE 1600] avg return: -27.24%
# [EPISODE 1650] avg return: -28.76%
# [EPISODE 1700] avg return: -28.74%
# [EPISODE 1750] avg return: -29.06%
# [EPISODE 1800] avg return: -26.15%
# [EPISODE 1850] avg return: -28.94%
# [EPISODE 1900] avg return: -29.56%
# [EPISODE 1950] avg return: -29.63%
# [EPISODE 2000] avg return: -29.76%
# [EPISODE 2050] avg return: -27.69%
# [EPISODE 2100] avg return: -26.29%
# [EPISODE 2150] avg return: -28.37%
# [EPISODE 2200] avg return: -30.18%
# [EPISODE 2250] avg return: -31.70%
# [EPISODE 2300] avg return: -28.05%
# [EPISODE 2350] avg return: -28.99%
# [EPISODE 2400] avg return: -30.42%
# [EPISODE 2450] avg return: -27.54%
# [EPISODE 2500] avg return: -27.68%
# [EPISODE 2550] avg return: -31.31%
# [EPISODE 2600] avg return: -27.67%
# [EPISODE 2650] avg return: -28.32%
# [EPISODE 2700] avg return: -31.74%
# [EPISODE 2750] avg return: -28.48%
# [EPISODE 2800] avg return: -32.20%
# [EPISODE 2850] avg return: -30.04%
# [EPISODE 2900] avg return: -32.31%
# [EPISODE 2950] avg return: -32.59%
# [EPISODE 3000] avg return: -31.12%
# [EPISODE 3050] avg return: -29.54%
# [EPISODE 3100] avg return: -28.05%
# [EPISODE 3150] avg return: -29.95%
# [EPISODE 3200] avg return: -30.01%
# [EPISODE 3250] avg return: -28.66%
# [EPISODE 3300] avg return: -29.68%
# [EPISODE 3350] avg return: -30.43%
# [EPISODE 3400] avg return: -28.29%
# [EPISODE 3450] avg return: -27.51%
# [EPISODE 3500] avg return: -29.01%
# [EPISODE 3550] avg return: -29.42%
# [EPISODE 3600] avg return: -29.01%
# [EPISODE 3650] avg return: -29.94%
# [EPISODE 3700] avg return: -25.57%
# [EPISODE 3750] avg return: -29.22%
# [EPISODE 3800] avg return: -30.53%
# [EPISODE 3850] avg return: -27.55%
# [EPISODE 3900] avg return: -28.19%
# [EPISODE 3950] avg return: -29.48%
# [EPISODE 4000] avg return: -27.19%
# [EPISODE 4050] avg return: -29.41%
# [EPISODE 4100] avg return: -30.20%
# [EPISODE 4150] avg return: -27.27%
# [EPISODE 4200] avg return: -28.97%
# [EPISODE 4250] avg return: -29.66%
# [EPISODE 4300] avg return: -31.57%
# [EPISODE 4350] avg return: -24.24%
# [EPISODE 4400] avg return: -30.20%
# [EPISODE 4450] avg return: -30.48%
# [EPISODE 4500] avg return: -31.41%
# [EPISODE 4550] avg return: -31.52%
# [EPISODE 4600] avg return: -30.29%
# [EPISODE 4650] avg return: -25.62%
# [EPISODE 4700] avg return: -28.73%
# [EPISODE 4750] avg return: -28.00%
# [EPISODE 4800] avg return: -30.45%
# [EPISODE 4850] avg return: -27.84%
# [EPISODE 4900] avg return: -27.71%
# [EPISODE 4950] avg return: -28.86%
# [EPISODE 5000] avg return: -27.49%
# [EPISODE 5050] avg return: -30.78%
# [EPISODE 5100] avg return: -30.27%
# [EPISODE 5150] avg return: -28.94%
# [EPISODE 5200] avg return: -30.79%
# [EPISODE 5250] avg return: -32.69%
# [EPISODE 5300] avg return: -30.07%
# [EPISODE 5350] avg return: -28.24%
# [EPISODE 5400] avg return: -29.11%
# [EPISODE 5450] avg return: -30.70%
# [EPISODE 5500] avg return: -28.80%
# [EPISODE 5550] avg return: -27.26%
# [EPISODE 5600] avg return: -27.59%
# [EPISODE 5650] avg return: -27.66%
# [EPISODE 5700] avg return: -26.89%
# [EPISODE 5750] avg return: -28.30%
# [EPISODE 5800] avg return: -28.36%
# [EPISODE 5850] avg return: -29.99%
# [EPISODE 5900] avg return: -28.55%
# [EPISODE 5950] avg return: -29.87%
# [EPISODE 6000] avg return: -26.62%
# [EPISODE 6050] avg return: -30.51%
# [EPISODE 6100] avg return: -30.53%
# [EPISODE 6150] avg return: -28.67%
# [EPISODE 6200] avg return: -29.30%
# [EPISODE 6250] avg return: -28.06%
# [EPISODE 6300] avg return: -29.41%
# [EPISODE 6350] avg return: -27.33%
# [EPISODE 6400] avg return: -30.79%
# [EPISODE 6450] avg return: -29.54%
# [EPISODE 6500] avg return: -26.93%
# [EPISODE 6550] avg return: -28.80%
# [EPISODE 6600] avg return: -26.42%
# [EPISODE 6650] avg return: -27.95%
# [EPISODE 6700] avg return: -30.88%
# [EPISODE 6750] avg return: -31.25%
# [EPISODE 6800] avg return: -30.89%
# [EPISODE 6850] avg return: -29.79%
# [EPISODE 6900] avg return: -28.83%
# [EPISODE 6950] avg return: -27.82%
# [EPISODE 7000] avg return: -30.86%
# [EPISODE 7050] avg return: -29.24%
# [EPISODE 7100] avg return: -29.41%
# [EPISODE 7150] avg return: -29.21%
# [EPISODE 7200] avg return: -26.87%
# [EPISODE 7250] avg return: -30.70%
# [EPISODE 7300] avg return: -31.48%
# [EPISODE 7350] avg return: -27.01%
# [EPISODE 7400] avg return: -28.75%
# [EPISODE 7450] avg return: -29.98%
# [EPISODE 7500] avg return: -25.25%
# [EPISODE 7550] avg return: -29.55%
# [EPISODE 7600] avg return: -29.70%
# [EPISODE 7650] avg return: -30.58%
# [EPISODE 7700] avg return: -30.64%
# [EPISODE 7750] avg return: -28.12%
# [EPISODE 7800] avg return: -30.85%
# [EPISODE 7850] avg return: -31.53%
# [EPISODE 7900] avg return: -33.16%
# [EPISODE 7950] avg return: -28.35%
# [EPISODE 8000] avg return: -27.69%
# [EPISODE 8050] avg return: -28.34%
# [EPISODE 8100] avg return: -27.27%
# [EPISODE 8150] avg return: -29.44%
# [EPISODE 8200] avg return: -30.61%
# [EPISODE 8250] avg return: -26.72%
# [EPISODE 8300] avg return: -30.80%
# [EPISODE 8350] avg return: -29.26%
# [EPISODE 8400] avg return: -26.17%
# [EPISODE 8450] avg return: -30.50%
# [EPISODE 8500] avg return: -29.05%
# [EPISODE 8550] avg return: -29.65%
# [EPISODE 8600] avg return: -29.23%
# [EPISODE 8650] avg return: -30.61%
# [EPISODE 8700] avg return: -28.50%
# [EPISODE 8750] avg return: -30.72%
# [EPISODE 8800] avg return: -29.81%
# [EPISODE 8850] avg return: -27.29%
# [EPISODE 8900] avg return: -32.21%
# [EPISODE 8950] avg return: -33.93%
# [EPISODE 9000] avg return: -33.58%
# [EPISODE 9050] avg return: -38.20%
# [EPISODE 9100] avg return: -34.13%
# [EPISODE 9150] avg return: -35.85%
# [EPISODE 9200] avg return: -35.61%
# [EPISODE 9250] avg return: -38.84%
# [EPISODE 9300] avg return: -34.94%
# [EPISODE 9350] avg return: -37.45%
# [EPISODE 9400] avg return: -34.48%
# [EPISODE 9450] avg return: -37.57%
# [EPISODE 9500] avg return: -34.32%
# [EPISODE 9550] avg return: -36.75%
# [EPISODE 9600] avg return: -34.85%
# [EPISODE 9650] avg return: -37.39%
# [EPISODE 9700] avg return: -34.59%
# [EPISODE 9750] avg return: -36.54%
# [EPISODE 9800] avg return: -37.40%
# [EPISODE 9850] avg return: -37.87%
# [EPISODE 9900] avg return: -35.64%
# [EPISODE 9950] avg return: -36.96%
# [EPISODE 10000] avg return: -36.50%
# [EPISODE 10050] avg return: -37.52%
# [EPISODE 10100] avg return: -37.21%
# [EPISODE 10150] avg return: -37.76%
# [EPISODE 10200] avg return: -35.94%
# [EPISODE 10250] avg return: -34.21%
# [EPISODE 10300] avg return: -34.54%
# [EPISODE 10350] avg return: -35.81%
# [EPISODE 10400] avg return: -35.34%
# [EPISODE 10450] avg return: -33.90%
# [EPISODE 10500] avg return: -39.04%
# [EPISODE 10550] avg return: -36.43%
# [EPISODE 10600] avg return: -34.93%
# [EPISODE 10650] avg return: -35.07%
# [EPISODE 10700] avg return: -39.57%
# [EPISODE 10750] avg return: -36.73%
# [EPISODE 10800] avg return: -35.67%
# [EPISODE 10850] avg return: -38.16%
# [EPISODE 10900] avg return: -36.45%
# [EPISODE 10950] avg return: -37.29%
# [EPISODE 11000] avg return: -36.20%
# [EPISODE 11050] avg return: -36.52%
# [EPISODE 11100] avg return: -34.91%
# [EPISODE 11150] avg return: -36.60%
# [EPISODE 11200] avg return: -37.97%
# [EPISODE 11250] avg return: -36.12%
# [EPISODE 11300] avg return: -35.90%
# [EPISODE 11350] avg return: -38.82%
# [EPISODE 11400] avg return: -37.29%
# [EPISODE 11450] avg return: -35.12%
# [EPISODE 11500] avg return: -37.25%
# [EPISODE 11550] avg return: -37.44%
# [EPISODE 11600] avg return: -33.15%
# [EPISODE 11650] avg return: -34.05%
# [EPISODE 11700] avg return: -35.75%
# [EPISODE 11750] avg return: -34.41%
# [EPISODE 11800] avg return: -36.96%
# [EPISODE 11850] avg return: -37.80%
# [EPISODE 11900] avg return: -39.28%
# [EPISODE 11950] avg return: -36.15%
# [EPISODE 12000] avg return: -37.10%
# [EPISODE 12050] avg return: -35.94%
# [EPISODE 12100] avg return: -36.88%
# [EPISODE 12150] avg return: -38.13%
# [EPISODE 12200] avg return: -36.84%
# [EPISODE 12250] avg return: -34.90%
# [EPISODE 12300] avg return: -37.63%
# [EPISODE 12350] avg return: -35.70%
# [EPISODE 12400] avg return: -37.47%
# [EPISODE 12450] avg return: -35.29%
# [EPISODE 12500] avg return: -34.60%
# [EPISODE 12550] avg return: -35.33%
# [EPISODE 12600] avg return: -37.47%
# [EPISODE 12650] avg return: -34.81%
# [EPISODE 12700] avg return: -37.04%
# [EPISODE 12750] avg return: -37.20%
# [EPISODE 12800] avg return: -35.73%
# [EPISODE 12850] avg return: -36.91%
# [EPISODE 12900] avg return: -36.14%
# [EPISODE 12950] avg return: -35.57%
# [EPISODE 13000] avg return: -37.32%
# [EPISODE 13050] avg return: -35.76%
# [EPISODE 13100] avg return: -34.35%
# [EPISODE 13150] avg return: -34.47%
# [EPISODE 13200] avg return: -37.77%
# [EPISODE 13250] avg return: -34.29%
# [EPISODE 13300] avg return: -34.73%
# [EPISODE 13350] avg return: -36.70%
# [EPISODE 13400] avg return: -36.00%
# [EPISODE 13450] avg return: -36.56%
# [EPISODE 13500] avg return: -37.35%
# [EPISODE 13550] avg return: -35.32%
# [EPISODE 13600] avg return: -35.88%
# [EPISODE 13650] avg return: -37.62%
# [EPISODE 13700] avg return: -37.55%
# [EPISODE 13750] avg return: -34.25%
# [EPISODE 13800] avg return: -37.29%
# [EPISODE 13850] avg return: -40.00%
# [EPISODE 13900] avg return: -35.02%
# [EPISODE 13950] avg return: -37.79%
# [EPISODE 14000] avg return: -36.20%
# [EPISODE 14050] avg return: -35.00%
# [EPISODE 14100] avg return: -37.88%
# [EPISODE 14150] avg return: -34.32%
# [EPISODE 14200] avg return: -33.52%
# [EPISODE 14250] avg return: -37.36%
# [EPISODE 14300] avg return: -36.91%
# [EPISODE 14350] avg return: -36.41%
# [EPISODE 14400] avg return: -36.53%
# [EPISODE 14450] avg return: -38.43%
# [EPISODE 14500] avg return: -36.19%
# [EPISODE 14550] avg return: -33.46%
# [EPISODE 14600] avg return: -37.19%
# [EPISODE 14650] avg return: -35.03%
# [EPISODE 14700] avg return: -36.31%
# [EPISODE 14750] avg return: -34.45%
# [EPISODE 14800] avg return: -37.37%
# [EPISODE 14850] avg return: -34.86%
# [EPISODE 14900] avg return: -38.18%
# [EPISODE 14950] avg return: -36.87%
# [EPISODE 15000] avg return: -33.58%
# [EPISODE 15050] avg return: -36.34%
# [EPISODE 15100] avg return: -34.76%
# [EPISODE 15150] avg return: -36.73%
# [EPISODE 15200] avg return: -38.27%
# [EPISODE 15250] avg return: -38.21%
# [EPISODE 15300] avg return: -37.11%
# [EPISODE 15350] avg return: -36.23%
# [EPISODE 15400] avg return: -36.46%
# [EPISODE 15450] avg return: -35.67%
# [EPISODE 15500] avg return: -33.26%
# [EPISODE 15550] avg return: -35.24%
# [EPISODE 15600] avg return: -35.38%
# [EPISODE 15650] avg return: -35.00%
# [EPISODE 15700] avg return: -37.18%
# [EPISODE 15750] avg return: -36.17%
# [EPISODE 15800] avg return: -36.26%
# [EPISODE 15850] avg return: -37.72%
# [EPISODE 15900] avg return: -36.82%
# [EPISODE 15950] avg return: -34.46%
# [EPISODE 16000] avg return: -36.14%
# [EPISODE 16050] avg return: -37.41%
# [EPISODE 16100] avg return: -36.80%
# [EPISODE 16150] avg return: -35.46%
# [EPISODE 16200] avg return: -35.26%
# [EPISODE 16250] avg return: -35.01%
# [EPISODE 16300] avg return: -35.31%
# [EPISODE 16350] avg return: -36.34%
# [EPISODE 16400] avg return: -36.44%
# [EPISODE 16450] avg return: -37.23%
# [EPISODE 16500] avg return: -36.68%
# [EPISODE 16550] avg return: -35.84%
# [EPISODE 16600] avg return: -36.26%
# [EPISODE 16650] avg return: -34.63%
# [EPISODE 16700] avg return: -41.42%
# [EPISODE 16750] avg return: -36.29%
# [EPISODE 16800] avg return: -34.63%
# [EPISODE 16850] avg return: -37.06%
# [EPISODE 16900] avg return: -36.40%
# [EPISODE 16950] avg return: -38.65%
# [EPISODE 17000] avg return: -36.00%
# [EPISODE 17050] avg return: -38.22%
# [EPISODE 17100] avg return: -38.17%
# [EPISODE 17150] avg return: -34.89%
# [EPISODE 17200] avg return: -34.43%
# [EPISODE 17250] avg return: -36.60%
# [EPISODE 17300] avg return: -38.76%
# [EPISODE 17350] avg return: -30.70%
# [EPISODE 17400] avg return: -37.30%
# [EPISODE 17450] avg return: -37.34%
# [EPISODE 17500] avg return: -37.89%
# [EPISODE 17550] avg return: -36.13%
# [EPISODE 17600] avg return: -39.19%
# [EPISODE 17650] avg return: -35.43%
# [EPISODE 17700] avg return: -39.60%
# [EPISODE 17750] avg return: -35.63%
# [EPISODE 17800] avg return: -32.62%
# [EPISODE 17850] avg return: -36.85%
# [EPISODE 17900] avg return: -36.37%
# [EPISODE 17950] avg return: -35.88%
# [EPISODE 18000] avg return: -36.91%
# [EPISODE 18050] avg return: -35.89%
# [EPISODE 18100] avg return: -35.85%
# [EPISODE 18150] avg return: -37.87%
# [EPISODE 18200] avg return: -39.42%
# [EPISODE 18250] avg return: -33.40%
# [EPISODE 18300] avg return: -39.33%
# [EPISODE 18350] avg return: -35.04%
# [EPISODE 18400] avg return: -35.68%
# [EPISODE 18450] avg return: -33.86%
# [EPISODE 18500] avg return: -34.01%
# [EPISODE 18550] avg return: -36.63%
# [EPISODE 18600] avg return: -36.11%
# [EPISODE 18650] avg return: -37.33%
# [EPISODE 18700] avg return: -34.92%
# [EPISODE 18750] avg return: -37.35%
# [EPISODE 18800] avg return: -34.46%
# [EPISODE 18850] avg return: -34.90%
# [EPISODE 18900] avg return: -38.06%
# [EPISODE 18950] avg return: -34.94%
# [EPISODE 19000] avg return: -34.74%
# [EPISODE 19050] avg return: -35.55%
# [EPISODE 19100] avg return: -34.63%
# [EPISODE 19150] avg return: -37.54%
# [EPISODE 19200] avg return: -35.19%
# [EPISODE 19250] avg return: -35.77%
# [EPISODE 19300] avg return: -34.73%
# [EPISODE 19350] avg return: -35.15%
# [EPISODE 19400] avg return: -38.35%
# [EPISODE 19450] avg return: -35.50%
# [EPISODE 19500] avg return: -34.12%
# [EPISODE 19550] avg return: -34.13%
# [EPISODE 19600] avg return: -36.03%
# [EPISODE 19650] avg return: -34.98%
# [EPISODE 19700] avg return: -35.92%
# [EPISODE 19750] avg return: -30.31%
# [EPISODE 19800] avg return: -33.45%
# [EPISODE 19850] avg return: -34.37%
# [EPISODE 19900] avg return: -35.61%
# [EPISODE 19950] avg return: -37.95%
# [EPISODE 20000] avg return: -36.10%
# [EPISODE 20050] avg return: -34.98%
# [EPISODE 20100] avg return: -38.60%
# [EPISODE 20150] avg return: -36.40%
# [EPISODE 20200] avg return: -34.21%
# [EPISODE 20250] avg return: -37.34%
# [EPISODE 20300] avg return: -38.11%
# [EPISODE 20350] avg return: -37.78%
# [EPISODE 20400] avg return: -35.62%
# [EPISODE 20450] avg return: -35.29%
# [EPISODE 20500] avg return: -37.18%
# [EPISODE 20550] avg return: -35.49%
# [EPISODE 20600] avg return: -38.06%
# [EPISODE 20650] avg return: -32.72%
# [EPISODE 20700] avg return: -35.43%
# [EPISODE 20750] avg return: -34.72%
# [EPISODE 20800] avg return: -35.62%
# [EPISODE 20850] avg return: -36.57%
# [EPISODE 20900] avg return: -35.11%
# [EPISODE 20950] avg return: -35.82%
# [EPISODE 21000] avg return: -38.74%
# [EPISODE 21050] avg return: -36.56%
# [EPISODE 21100] avg return: -37.58%
# [EPISODE 21150] avg return: -34.89%
# [EPISODE 21200] avg return: -34.57%
# [EPISODE 21250] avg return: -36.32%
# [EPISODE 21300] avg return: -37.57%
# [EPISODE 21350] avg return: -35.42%
# [EPISODE 21400] avg return: -36.75%
# [EPISODE 21450] avg return: -35.39%
# [EPISODE 21500] avg return: -35.36%
# [EPISODE 21550] avg return: -36.98%
# [EPISODE 21600] avg return: -36.67%
# [EPISODE 21650] avg return: -34.69%
# [EPISODE 21700] avg return: -34.45%
# [EPISODE 21750] avg return: -32.73%
# [EPISODE 21800] avg return: -37.97%
# [EPISODE 21850] avg return: -37.70%
# [EPISODE 21900] avg return: -38.73%
# [EPISODE 21950] avg return: -36.82%
# [EPISODE 22000] avg return: -35.87%
# [EPISODE 22050] avg return: -39.33%
# [EPISODE 22100] avg return: -34.04%
# [EPISODE 22150] avg return: -35.53%
# [EPISODE 22200] avg return: -36.46%
# [EPISODE 22250] avg return: -36.41%
# [EPISODE 22300] avg return: -40.24%
# [EPISODE 22350] avg return: -37.12%
# [EPISODE 22400] avg return: -36.16%
# [EPISODE 22450] avg return: -36.99%
# [EPISODE 22500] avg return: -35.74%
# [EPISODE 22550] avg return: -35.00%
# [EPISODE 22600] avg return: -37.92%
# [EPISODE 22650] avg return: -37.37%
# [EPISODE 22700] avg return: -35.28%
# [EPISODE 22750] avg return: -33.81%
# [EPISODE 22800] avg return: -36.50%
# [EPISODE 22850] avg return: -38.38%
# [EPISODE 22900] avg return: -35.34%
# [EPISODE 22950] avg return: -34.26%
# [EPISODE 23000] avg return: -37.81%
# [EPISODE 23050] avg return: -39.61%
# [EPISODE 23100] avg return: -35.76%
# [EPISODE 23150] avg return: -34.13%
# [EPISODE 23200] avg return: -40.31%
# [EPISODE 23250] avg return: -36.17%
# [EPISODE 23300] avg return: -36.58%
# [EPISODE 23350] avg return: -34.59%
# [EPISODE 23400] avg return: -32.92%
# [EPISODE 23450] avg return: -36.01%
# [EPISODE 23500] avg return: -31.98%
# [EPISODE 23550] avg return: -34.46%
# [EPISODE 23600] avg return: -35.24%
# [EPISODE 23650] avg return: -40.17%
# [EPISODE 23700] avg return: -37.42%
# [EPISODE 23750] avg return: -35.22%
# [EPISODE 23800] avg return: -38.02%
# [EPISODE 23850] avg return: -37.25%
# [EPISODE 23900] avg return: -35.68%
# [EPISODE 23950] avg return: -36.01%
# [EPISODE 24000] avg return: -36.14%
# [EPISODE 24050] avg return: -37.76%
# [EPISODE 24100] avg return: -33.28%
# [EPISODE 24150] avg return: -36.00%
# [EPISODE 24200] avg return: -38.77%
# [EPISODE 24250] avg return: -36.61%
# [EPISODE 24300] avg return: -37.84%
# [EPISODE 24350] avg return: -34.87%
# [EPISODE 24400] avg return: -38.13%
# [EPISODE 24450] avg return: -36.88%
# [EPISODE 24500] avg return: -34.92%
# [EPISODE 24550] avg return: -36.64%
# [EPISODE 24600] avg return: -38.48%
# [EPISODE 24650] avg return: -36.58%
# [EPISODE 24700] avg return: -38.46%
# [EPISODE 24750] avg return: -37.93%
# [EPISODE 24800] avg return: -36.84%
# [EPISODE 24850] avg return: -35.16%
# [EPISODE 24900] avg return: -36.34%
# [EPISODE 24950] avg return: -37.49%
# [EPISODE 25000] avg return: -34.86%
# [EPISODE 25050] avg return: -35.36%
# [EPISODE 25100] avg return: -34.65%
# [EPISODE 25150] avg return: -36.66%
# [EPISODE 25200] avg return: -32.55%
# [EPISODE 25250] avg return: -39.08%
# [EPISODE 25300] avg return: -34.45%
# [EPISODE 25350] avg return: -35.67%
# [EPISODE 25400] avg return: -35.45%
# [EPISODE 25450] avg return: -35.25%
# [EPISODE 25500] avg return: -37.45%
# [EPISODE 25550] avg return: -34.95%
# [EPISODE 25600] avg return: -37.92%
# [EPISODE 25650] avg return: -33.39%
# [EPISODE 25700] avg return: -37.49%
# [EPISODE 25750] avg return: -39.13%
# [EPISODE 25800] avg return: -33.85%
# [EPISODE 25850] avg return: -36.12%
# [EPISODE 25900] avg return: -33.58%
# [EPISODE 25950] avg return: -35.61%
# [EPISODE 26000] avg return: -37.81%
# [EPISODE 26050] avg return: -35.05%
# [EPISODE 26100] avg return: -38.54%
# [EPISODE 26150] avg return: -36.86%
# [EPISODE 26200] avg return: -37.49%
# [EPISODE 26250] avg return: -39.08%
# [EPISODE 26300] avg return: -38.20%
# [EPISODE 26350] avg return: -35.81%
# [EPISODE 26400] avg return: -37.73%
# [EPISODE 26450] avg return: -35.61%
# [EPISODE 26500] avg return: -35.32%
# [EPISODE 26550] avg return: -35.28%
# [EPISODE 26600] avg return: -39.16%
# [EPISODE 26650] avg return: -35.38%
# [EPISODE 26700] avg return: -34.26%
# [EPISODE 26750] avg return: -32.36%
# [EPISODE 26800] avg return: -34.73%
# [EPISODE 26850] avg return: -32.73%
# [EPISODE 26900] avg return: -33.87%
# [EPISODE 26950] avg return: -32.75%
# [EPISODE 27000] avg return: -34.66%
# [EPISODE 27050] avg return: -32.90%
# [EPISODE 27100] avg return: -35.34%
# [EPISODE 27150] avg return: -32.70%
# [EPISODE 27200] avg return: -34.05%
# [EPISODE 27250] avg return: -33.74%
# [EPISODE 27300] avg return: -34.51%
# [EPISODE 27350] avg return: -32.84%
# [EPISODE 27400] avg return: -34.37%
# [EPISODE 27450] avg return: -30.97%
# [EPISODE 27500] avg return: -34.11%
# [EPISODE 27550] avg return: -32.72%
# [EPISODE 27600] avg return: -32.79%
# [EPISODE 27650] avg return: -33.42%
# [EPISODE 27700] avg return: -29.59%
# [EPISODE 27750] avg return: -33.77%
# [EPISODE 27800] avg return: -34.71%
# [EPISODE 27850] avg return: -34.62%
# [EPISODE 27900] avg return: -32.37%
# [EPISODE 27950] avg return: -33.84%
# [EPISODE 28000] avg return: -34.91%
# [EPISODE 28050] avg return: -34.00%
# [EPISODE 28100] avg return: -32.23%
# [EPISODE 28150] avg return: -33.21%
# [EPISODE 28200] avg return: -33.39%
# [EPISODE 28250] avg return: -33.83%
# [EPISODE 28300] avg return: -32.29%
# [EPISODE 28350] avg return: -30.44%
# [EPISODE 28400] avg return: -33.11%
# [EPISODE 28450] avg return: -33.72%
# [EPISODE 28500] avg return: -32.93%
# [EPISODE 28550] avg return: -31.29%
# [EPISODE 28600] avg return: -32.62%
# [EPISODE 28650] avg return: -35.41%
# [EPISODE 28700] avg return: -30.52%
# [EPISODE 28750] avg return: -32.15%
# [EPISODE 28800] avg return: -32.41%
# [EPISODE 28850] avg return: -31.20%
# [EPISODE 28900] avg return: -31.20%
# [EPISODE 28950] avg return: -33.63%
# [EPISODE 29000] avg return: -34.54%
# [EPISODE 29050] avg return: -32.44%
# [EPISODE 29100] avg return: -31.39%
# [EPISODE 29150] avg return: -34.17%
# [EPISODE 29200] avg return: -34.04%
# [EPISODE 29250] avg return: -31.32%
# [EPISODE 29300] avg return: -34.02%
# [EPISODE 29350] avg return: -33.95%
# [EPISODE 29400] avg return: -33.79%
# [EPISODE 29450] avg return: -33.43%
# [EPISODE 29500] avg return: -34.09%
# [EPISODE 29550] avg return: -33.86%
# [EPISODE 29600] avg return: -33.32%
# [EPISODE 29650] avg return: -34.64%
# [EPISODE 29700] avg return: -32.65%
# [EPISODE 29750] avg return: -31.46%
# [EPISODE 29800] avg return: -33.74%
# [EPISODE 29850] avg return: -32.90%
# [EPISODE 29900] avg return: -32.75%
# [EPISODE 29950] avg return: -32.97%
# [EPISODE 30000] avg return: -34.31%
# [EPISODE 30050] avg return: -32.34%
# [EPISODE 30100] avg return: -33.04%
# [EPISODE 30150] avg return: -35.10%
# [EPISODE 30200] avg return: -33.84%
# [EPISODE 30250] avg return: -33.24%
# [EPISODE 30300] avg return: -33.06%
# [EPISODE 30350] avg return: -34.36%
# [EPISODE 30400] avg return: -32.58%
# [EPISODE 30450] avg return: -34.09%
# [EPISODE 30500] avg return: -34.48%
# [EPISODE 30550] avg return: -33.19%
# [EPISODE 30600] avg return: -31.94%
# [EPISODE 30650] avg return: -33.05%
# [EPISODE 30700] avg return: -34.30%
# [EPISODE 30750] avg return: -33.48%
# [EPISODE 30800] avg return: -33.15%
# [EPISODE 30850] avg return: -31.09%
# [EPISODE 30900] avg return: -34.83%
# [EPISODE 30950] avg return: -33.04%
# [EPISODE 31000] avg return: -34.39%
# [EPISODE 31050] avg return: -33.11%
# [EPISODE 31100] avg return: -33.54%
# [EPISODE 31150] avg return: -33.39%
# [EPISODE 31200] avg return: -33.65%
# [EPISODE 31250] avg return: -31.63%
# [EPISODE 31300] avg return: -32.85%
# [EPISODE 31350] avg return: -33.14%
# [EPISODE 31400] avg return: -33.86%
# [EPISODE 31450] avg return: -32.90%
# [EPISODE 31500] avg return: -34.09%
# [EPISODE 31550] avg return: -32.01%
# [EPISODE 31600] avg return: -34.46%
# [EPISODE 31650] avg return: -36.74%
# [EPISODE 31700] avg return: -32.35%
# [EPISODE 31750] avg return: -34.11%
# [EPISODE 31800] avg return: -31.73%
# [EPISODE 31850] avg return: -32.66%
# [EPISODE 31900] avg return: -34.25%
# [EPISODE 31950] avg return: -31.65%
# [EPISODE 32000] avg return: -31.36%
# [EPISODE 32050] avg return: -32.20%
# [EPISODE 32100] avg return: -31.06%
# [EPISODE 32150] avg return: -34.26%
# [EPISODE 32200] avg return: -33.61%
# [EPISODE 32250] avg return: -34.72%
# [EPISODE 32300] avg return: -33.60%
# [EPISODE 32350] avg return: -32.76%
# [EPISODE 32400] avg return: -34.64%
# [EPISODE 32450] avg return: -33.74%
# [EPISODE 32500] avg return: -31.06%
# [EPISODE 32550] avg return: -33.66%
# [EPISODE 32600] avg return: -31.89%
# [EPISODE 32650] avg return: -32.56%
# [EPISODE 32700] avg return: -32.24%
# [EPISODE 32750] avg return: -35.49%
# [EPISODE 32800] avg return: -33.97%
# [EPISODE 32850] avg return: -33.64%
# [EPISODE 32900] avg return: -35.46%
# [EPISODE 32950] avg return: -33.38%
# [EPISODE 33000] avg return: -32.39%
# [EPISODE 33050] avg return: -32.52%
# [EPISODE 33100] avg return: -34.80%
# [EPISODE 33150] avg return: -33.07%
# [EPISODE 33200] avg return: -33.61%
# [EPISODE 33250] avg return: -33.03%
# [EPISODE 33300] avg return: -30.24%
# [EPISODE 33350] avg return: -34.59%
# [EPISODE 33400] avg return: -29.57%
# [EPISODE 33450] avg return: -32.23%
# [EPISODE 33500] avg return: -32.80%
# [EPISODE 33550] avg return: -32.05%
# [EPISODE 33600] avg return: -33.32%
# [EPISODE 33650] avg return: -32.11%
# [EPISODE 33700] avg return: -33.05%
# [EPISODE 33750] avg return: -31.48%
# [EPISODE 33800] avg return: -33.38%
# [EPISODE 33850] avg return: -33.61%
# [EPISODE 33900] avg return: -32.32%
# [EPISODE 33950] avg return: -32.44%
# [EPISODE 34000] avg return: -32.95%
# [EPISODE 34050] avg return: -34.10%
# [EPISODE 34100] avg return: -30.44%
# [EPISODE 34150] avg return: -33.35%
# [EPISODE 34200] avg return: -33.81%
# [EPISODE 34250] avg return: -34.61%
# [EPISODE 34300] avg return: -33.58%
# [EPISODE 34350] avg return: -32.20%
# [EPISODE 34400] avg return: -33.13%
# [EPISODE 34450] avg return: -34.42%
# [EPISODE 34500] avg return: -33.64%
# [EPISODE 34550] avg return: -33.04%
# [EPISODE 34600] avg return: -32.12%
# [EPISODE 34650] avg return: -33.76%
# [EPISODE 34700] avg return: -34.34%
# [EPISODE 34750] avg return: -32.98%
# [EPISODE 34800] avg return: -32.62%
# [EPISODE 34850] avg return: -32.65%
# [EPISODE 34900] avg return: -30.76%
# [EPISODE 34950] avg return: -34.22%
# [EPISODE 35000] avg return: -35.53%
# [EPISODE 35050] avg return: -32.68%
# [EPISODE 35100] avg return: -32.71%
# [EPISODE 35150] avg return: -33.99%
# [EPISODE 35200] avg return: -33.42%
# [EPISODE 35250] avg return: -29.09%
# [EPISODE 35300] avg return: -32.17%
# [EPISODE 35350] avg return: -33.02%
# [EPISODE 35400] avg return: -32.57%
# [EPISODE 35450] avg return: -33.42%
# [EPISODE 35500] avg return: -35.66%
# [EPISODE 35550] avg return: -33.52%
# [EPISODE 35600] avg return: -32.52%
# [EPISODE 35650] avg return: -32.04%
# [EPISODE 35700] avg return: -33.92%
# [EPISODE 35750] avg return: -33.89%
# [EPISODE 35800] avg return: -30.71%
# [EPISODE 35850] avg return: -32.74%
# [EPISODE 35900] avg return: -31.64%
# [EPISODE 35950] avg return: -32.88%
# [EPISODE 36000] avg return: -32.89%
# [EPISODE 36050] avg return: -33.52%
# [EPISODE 36100] avg return: -32.22%
# [EPISODE 36150] avg return: -34.03%
# [EPISODE 36200] avg return: -32.68%
# [EPISODE 36250] avg return: -34.08%
# [EPISODE 36300] avg return: -31.99%
# [EPISODE 36350] avg return: -34.26%
# [EPISODE 36400] avg return: -31.67%
# [EPISODE 36450] avg return: -30.98%
# [EPISODE 36500] avg return: -35.00%
# [EPISODE 36550] avg return: -33.43%
# [EPISODE 36600] avg return: -33.39%
# [EPISODE 36650] avg return: -35.32%
# [EPISODE 36700] avg return: -33.24%
# [EPISODE 36750] avg return: -33.33%
# [EPISODE 36800] avg return: -30.68%
# [EPISODE 36850] avg return: -33.48%
# [EPISODE 36900] avg return: -33.47%
# [EPISODE 36950] avg return: -31.53%
# [EPISODE 37000] avg return: -33.08%
# [EPISODE 37050] avg return: -35.19%
# [EPISODE 37100] avg return: -33.47%
# [EPISODE 37150] avg return: -32.65%
# [EPISODE 37200] avg return: -32.44%
# [EPISODE 37250] avg return: -33.05%
# [EPISODE 37300] avg return: -32.44%
# [EPISODE 37350] avg return: -32.62%
# [EPISODE 37400] avg return: -31.95%
# [EPISODE 37450] avg return: -33.74%
# [EPISODE 37500] avg return: -31.96%
# [EPISODE 37550] avg return: -34.85%
# [EPISODE 37600] avg return: -31.76%
# [EPISODE 37650] avg return: -32.99%
# [EPISODE 37700] avg return: -33.65%
# [EPISODE 37750] avg return: -33.08%
# [EPISODE 37800] avg return: -34.52%
# [EPISODE 37850] avg return: -32.75%
# [EPISODE 37900] avg return: -32.18%
# [EPISODE 37950] avg return: -34.55%
# [EPISODE 38000] avg return: -33.93%
# [EPISODE 38050] avg return: -33.85%
# [EPISODE 38100] avg return: -33.46%
# [EPISODE 38150] avg return: -31.23%
# [EPISODE 38200] avg return: -31.59%
# [EPISODE 38250] avg return: -33.16%
# [EPISODE 38300] avg return: -31.43%
# [EPISODE 38350] avg return: -33.25%
# [EPISODE 38400] avg return: -32.79%
# [EPISODE 38450] avg return: -33.10%
# [EPISODE 38500] avg return: -35.14%
# [EPISODE 38550] avg return: -31.45%
# [EPISODE 38600] avg return: -36.48%
# [EPISODE 38650] avg return: -34.81%
# [EPISODE 38700] avg return: -31.68%
# [EPISODE 38750] avg return: -34.89%
# [EPISODE 38800] avg return: -31.53%
# [EPISODE 38850] avg return: -32.56%
# [EPISODE 38900] avg return: -33.83%
# [EPISODE 38950] avg return: -31.18%
# [EPISODE 39000] avg return: -33.32%
# [EPISODE 39050] avg return: -34.34%
# [EPISODE 39100] avg return: -34.31%
# [EPISODE 39150] avg return: -32.61%
# [EPISODE 39200] avg return: -33.24%
# [EPISODE 39250] avg return: -32.80%
# [EPISODE 39300] avg return: -31.31%
# [EPISODE 39350] avg return: -30.71%
# [EPISODE 39400] avg return: -34.04%
# [EPISODE 39450] avg return: -32.95%
# [EPISODE 39500] avg return: -31.19%
# [EPISODE 39550] avg return: -31.53%
# [EPISODE 39600] avg return: -30.85%
# [EPISODE 39650] avg return: -30.29%
# [EPISODE 39700] avg return: -31.04%
# [EPISODE 39750] avg return: -33.31%
# [EPISODE 39800] avg return: -31.13%
# [EPISODE 39850] avg return: -32.78%
# [EPISODE 39900] avg return: -32.11%
# [EPISODE 39950] avg return: -31.89%
# [EPISODE 40000] avg return: -32.53%
# [EPISODE 40050] avg return: -32.45%
# [EPISODE 40100] avg return: -32.28%
# [EPISODE 40150] avg return: -32.22%
# [EPISODE 40200] avg return: -27.78%
# [EPISODE 40250] avg return: -33.04%
# [EPISODE 40300] avg return: -32.30%
# [EPISODE 40350] avg return: -35.30%
# [EPISODE 40400] avg return: -29.44%
# [EPISODE 40450] avg return: -32.66%
# [EPISODE 40500] avg return: -32.89%
# [EPISODE 40550] avg return: -30.40%
# [EPISODE 40600] avg return: -32.08%
# [EPISODE 40650] avg return: -29.08%
# [EPISODE 40700] avg return: -31.79%
# [EPISODE 40750] avg return: -32.42%
# [EPISODE 40800] avg return: -32.65%
# [EPISODE 40850] avg return: -33.42%
# [EPISODE 40900] avg return: -33.36%
# [EPISODE 40950] avg return: -33.80%
# [EPISODE 41000] avg return: -32.70%
# [EPISODE 41050] avg return: -33.06%
# [EPISODE 41100] avg return: -35.80%
# [EPISODE 41150] avg return: -34.00%
# [EPISODE 41200] avg return: -35.04%
# [EPISODE 41250] avg return: -33.33%
# [EPISODE 41300] avg return: -33.25%
# [EPISODE 41350] avg return: -31.71%
# [EPISODE 41400] avg return: -31.07%
# [EPISODE 41450] avg return: -33.26%
# [EPISODE 41500] avg return: -34.83%
# [EPISODE 41550] avg return: -33.13%
# [EPISODE 41600] avg return: -33.43%
# [EPISODE 41650] avg return: -32.47%
# [EPISODE 41700] avg return: -34.36%
# [EPISODE 41750] avg return: -32.03%
# [EPISODE 41800] avg return: -31.62%
# [EPISODE 41850] avg return: -32.52%
# [EPISODE 41900] avg return: -34.08%
# [EPISODE 41950] avg return: -32.30%
# [EPISODE 42000] avg return: -34.06%
# [EPISODE 42050] avg return: -32.74%
# [EPISODE 42100] avg return: -33.71%
# [EPISODE 42150] avg return: -30.73%
# [EPISODE 42200] avg return: -33.70%
# [EPISODE 42250] avg return: -30.62%
# [EPISODE 42300] avg return: -34.19%
# [EPISODE 42350] avg return: -29.00%
# [EPISODE 42400] avg return: -33.21%
# [EPISODE 42450] avg return: -31.33%
# [EPISODE 42500] avg return: -33.37%
# [EPISODE 42550] avg return: -31.86%
# [EPISODE 42600] avg return: -32.60%
# [EPISODE 42650] avg return: -31.30%
# [EPISODE 42700] avg return: -29.78%
# [EPISODE 42750] avg return: -31.06%
# [EPISODE 42800] avg return: -33.93%
# [EPISODE 42850] avg return: -31.73%
# [EPISODE 42900] avg return: -32.71%
# [EPISODE 42950] avg return: -32.37%
# [EPISODE 43000] avg return: -34.00%
# [EPISODE 43050] avg return: -33.29%
# [EPISODE 43100] avg return: -31.63%
# [EPISODE 43150] avg return: -32.82%
# [EPISODE 43200] avg return: -33.18%
# [EPISODE 43250] avg return: -30.69%
# [EPISODE 43300] avg return: -30.86%
# [EPISODE 43350] avg return: -33.69%
# [EPISODE 43400] avg return: -34.14%
# [EPISODE 43450] avg return: -31.36%
# [EPISODE 43500] avg return: -33.32%
# [EPISODE 43550] avg return: -33.78%
# [EPISODE 43600] avg return: -29.99%
# [EPISODE 43650] avg return: -29.61%
# [EPISODE 43700] avg return: -33.34%
# [EPISODE 43750] avg return: -32.33%
# [EPISODE 43800] avg return: -31.56%
# [EPISODE 43850] avg return: -34.78%
# [EPISODE 43900] avg return: -31.76%
# [EPISODE 43950] avg return: -31.99%
# [EPISODE 44000] avg return: -31.10%
# [EPISODE 44050] avg return: -29.95%
# [EPISODE 44100] avg return: -31.39%
# [EPISODE 44150] avg return: -31.96%
# [EPISODE 44200] avg return: -30.33%
# [EPISODE 44250] avg return: -31.64%
# [EPISODE 44300] avg return: -32.62%
# [EPISODE 44350] avg return: -31.05%
# [EPISODE 44400] avg return: -29.28%
# [EPISODE 44450] avg return: -30.14%
# [EPISODE 44500] avg return: -30.35%
# [EPISODE 44550] avg return: -32.29%
# [EPISODE 44600] avg return: -28.20%
# [EPISODE 44650] avg return: -31.59%
# [EPISODE 44700] avg return: -31.62%
# [EPISODE 44750] avg return: -31.04%
# [EPISODE 44800] avg return: -29.92%
# [EPISODE 44850] avg return: -31.19%
# [EPISODE 44900] avg return: -30.11%
# [EPISODE 44950] avg return: -32.16%
# [EPISODE 45000] avg return: -28.40%
# [EPISODE 45050] avg return: -33.72%
# [EPISODE 45100] avg return: -32.00%
# [EPISODE 45150] avg return: -33.22%
# [EPISODE 45200] avg return: -32.18%
# [EPISODE 45250] avg return: -32.02%
# [EPISODE 45300] avg return: -30.70%
# [EPISODE 45350] avg return: -27.95%
# [EPISODE 45400] avg return: -28.06%
# [EPISODE 45450] avg return: -31.39%
# [EPISODE 45500] avg return: -31.15%
# [EPISODE 45550] avg return: -29.82%
# [EPISODE 45600] avg return: -29.29%
# [EPISODE 45650] avg return: -28.73%
# [EPISODE 45700] avg return: -27.78%
# [EPISODE 45750] avg return: -30.20%
# [EPISODE 45800] avg return: -31.17%
# [EPISODE 45850] avg return: -31.06%
# [EPISODE 45900] avg return: -28.56%
# [EPISODE 45950] avg return: -30.61%
# [EPISODE 46000] avg return: -29.82%
# [EPISODE 46050] avg return: -28.97%
# [EPISODE 46100] avg return: -29.01%
# [EPISODE 46150] avg return: -27.86%
# [EPISODE 46200] avg return: -28.27%
# [EPISODE 46250] avg return: -29.25%
# [EPISODE 46300] avg return: -31.34%
# [EPISODE 46350] avg return: -29.88%
# [EPISODE 46400] avg return: -29.45%
# [EPISODE 46450] avg return: -30.88%
# [EPISODE 46500] avg return: -30.15%
# [EPISODE 46550] avg return: -29.76%
# [EPISODE 46600] avg return: -26.63%
# [EPISODE 46650] avg return: -29.86%
# [EPISODE 46700] avg return: -25.55%
# [EPISODE 46750] avg return: -29.43%
# [EPISODE 46800] avg return: -25.48%
# [EPISODE 46850] avg return: -29.61%
# [EPISODE 46900] avg return: -29.25%
# [EPISODE 46950] avg return: -29.61%
# [EPISODE 47000] avg return: -28.48%
# [EPISODE 47050] avg return: -31.12%
# [EPISODE 47100] avg return: -31.37%
# [EPISODE 47150] avg return: -32.11%
# [EPISODE 47200] avg return: -26.40%
# [EPISODE 47250] avg return: -28.67%
# [EPISODE 47300] avg return: -30.70%
# [EPISODE 47350] avg return: -30.16%
# [EPISODE 47400] avg return: -29.20%
# [EPISODE 47450] avg return: -28.32%
# [EPISODE 47500] avg return: -26.85%
# [EPISODE 47550] avg return: -27.47%
# [EPISODE 47600] avg return: -27.07%
# [EPISODE 47650] avg return: -27.60%
# [EPISODE 47700] avg return: -27.52%
# [EPISODE 47750] avg return: -30.87%
# [EPISODE 47800] avg return: -28.75%
# [EPISODE 47850] avg return: -29.03%
# [EPISODE 47900] avg return: -32.12%
# [EPISODE 47950] avg return: -28.78%
# [EPISODE 48000] avg return: -28.91%
# [EPISODE 48050] avg return: -30.61%
# [EPISODE 48100] avg return: -28.21%
# [EPISODE 48150] avg return: -30.38%
# [EPISODE 48200] avg return: -29.97%
# [EPISODE 48250] avg return: -28.70%
# [EPISODE 48300] avg return: -29.45%
# [EPISODE 48350] avg return: -31.40%
# [EPISODE 48400] avg return: -29.07%
# [EPISODE 48450] avg return: -26.25%
# [EPISODE 48500] avg return: -30.86%
# [EPISODE 48550] avg return: -26.43%
# [EPISODE 48600] avg return: -31.27%
# [EPISODE 48650] avg return: -29.59%
# [EPISODE 48700] avg return: -27.86%
# [EPISODE 48750] avg return: -26.33%
# [EPISODE 48800] avg return: -29.97%
# [EPISODE 48850] avg return: -30.92%
# [EPISODE 48900] avg return: -29.24%
# [EPISODE 48950] avg return: -27.57%
# [EPISODE 49000] avg return: -30.62%
# [EPISODE 49050] avg return: -28.84%
# [EPISODE 49100] avg return: -30.34%
# [EPISODE 49150] avg return: -31.29%
# [EPISODE 49200] avg return: -30.85%
# [EPISODE 49250] avg return: -28.81%
# [EPISODE 49300] avg return: -29.18%
# [EPISODE 49350] avg return: -29.80%
# [EPISODE 49400] avg return: -28.25%
# [EPISODE 49450] avg return: -31.74%
# [EPISODE 49500] avg return: -30.28%
# [EPISODE 49550] avg return: -29.93%
# [EPISODE 49600] avg return: -27.24%
# [EPISODE 49650] avg return: -28.47%
# [EPISODE 49700] avg return: -31.25%
# [EPISODE 49750] avg return: -30.41%
# [EPISODE 49800] avg return: -26.49%
# [EPISODE 49850] avg return: -30.09%
# [EPISODE 49900] avg return: -28.45%
# [EPISODE 49950] avg return: -28.49%
